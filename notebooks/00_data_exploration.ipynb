# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
DATA_RAW = PROJECT_ROOT / "data" / "raw"

df = pd.read_csv(DATA_RAW / "ai_student_impact_dataset__1_.csv")
print(df.shape)
# basic inspection
print(df.shape)
display(df.head())
display(df.info())
display(df.describe(include="all").T)

# missing values
missing = df.isna().sum().sort_values(ascending=False)
display(missing[missing > 0])

# value counts for categorical columns
cat_cols = df.select_dtypes(include=["object", "category"]).columns.tolist()
for col in cat_cols:
    print(f"\n{col} value counts:")
    display(df[col].value_counts(dropna=False).head(20))

# numeric distributions
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
df[num_cols].hist(figsize=(12, 8), bins=30, layout=(len(num_cols) // 3 + 1, 3))
plt.tight_layout()
plt.show()

# correlation heatmap
if len(num_cols) > 1:
    corr = df[num_cols].corr()
    plt.figure(figsize=(10, 8))
    sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", center=0)
    plt.title("Numeric feature correlations")
    plt.show()


# sample rows
display(df.sample(10, random_state=42))
# Out:
# (50000, 16)
# (50000, 16)
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# 1               5              False                    16.65
# 2               2              False                    10.35
# 3               4              False                    15.23
# 4               4              False                    12.55
#
#    Perceived_AI_Dependency   Institutional_Policy  Anxiety_Level_During_Exams  \
# 0                        5  Allowed_With_Citation                           6
# 1                        3  Allowed_With_Citation                           9
# 2                        5             Strict_Ban                           9
# 3                        2  Allowed_With_Citation                           2
# 4                        4  Allowed_With_Citation                           4
#
#    Post_Semester_GPA  Skill_Retention_Score Burnout_Risk_Level
# 0              2.393                  86.44               High
# 1              3.696                  69.39                Low
# 2              3.499                  73.93             Medium
# 3              4.000                  63.58             Medium
# 4              3.798                 100.00             Medium
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  50000 non-null  int64
#  1   Major_Category              50000 non-null  str
#  2   Year_of_Study               50000 non-null  str
#  3   Pre_Semester_GPA            50000 non-null  float64
#  4   Weekly_GenAI_Hours          50000 non-null  float64
#  5   Primary_Use_Case            50000 non-null  str
#  6   Prompt_Engineering_Skill    50000 non-null  str
#  7   Tool_Diversity              50000 non-null  int64
#  8   Paid_Subscription           50000 non-null  bool
#  9   Traditional_Study_Hours     50000 non-null  float64
#  10  Perceived_AI_Dependency     50000 non-null  int64
#  11  Institutional_Policy        50000 non-null  str
#  12  Anxiety_Level_During_Exams  50000 non-null  int64
#  13  Post_Semester_GPA           50000 non-null  float64
#  14  Skill_Retention_Score       50000 non-null  float64
#  15  Burnout_Risk_Level          50000 non-null  str
# dtypes: bool(1), float64(5), int64(4), str(6)
# memory usage: 5.8 MB
# None
#                               count unique                        top   freq  \
# Student_ID                  50000.0    NaN                        NaN    NaN
# Major_Category                50000      5                       STEM  15059
# Year_of_Study                 50000      5                     Junior  11045
# Pre_Semester_GPA            50000.0    NaN                        NaN    NaN
# Weekly_GenAI_Hours          50000.0    NaN                        NaN    NaN
# Primary_Use_Case              50000      5  Debugging/Troubleshooting  12295
# Prompt_Engineering_Skill      50000      3                   Beginner  18495
# Tool_Diversity              50000.0    NaN                        NaN    NaN
# Paid_Subscription             50000      2                      False  28846
# Traditional_Study_Hours     50000.0    NaN                        NaN    NaN
# Perceived_AI_Dependency     50000.0    NaN                        NaN    NaN
# Institutional_Policy          50000      3      Allowed_With_Citation  25224
# Anxiety_Level_During_Exams  50000.0    NaN                        NaN    NaN
# Post_Semester_GPA           50000.0    NaN                        NaN    NaN
# Skill_Retention_Score       50000.0    NaN                        NaN    NaN
# Burnout_Risk_Level            50000      3                     Medium  21144
#
#                                  mean           std       min        25%  \
# Student_ID                   125000.5  14433.901067  100001.0  112500.75
# Major_Category                    NaN           NaN       NaN        NaN
# Year_of_Study                     NaN           NaN       NaN        NaN
# Pre_Semester_GPA             3.146102      0.478854     1.183      2.834
# Weekly_GenAI_Hours           8.427752       8.26949       0.0       2.39
# Primary_Use_Case                  NaN           NaN       NaN        NaN
# Prompt_Engineering_Skill          NaN           NaN       NaN        NaN
# Tool_Diversity                2.80026       1.18802       1.0        2.0
# Paid_Subscription                 NaN           NaN       NaN        NaN
# Traditional_Study_Hours     11.209271      5.156426       1.0       7.56
# Perceived_AI_Dependency       3.50536      1.820812       1.0        2.0
# Institutional_Policy              NaN           NaN       NaN        NaN
# Anxiety_Level_During_Exams    4.27076      2.144066       1.0        3.0
# Post_Semester_GPA            3.349299      0.495673       1.0    3.02375
# Skill_Retention_Score       75.798125     13.281626     10.78      66.82
# Burnout_Risk_Level                NaN           NaN       NaN        NaN
#
#                                  50%        75%       max
# Student_ID                  125000.5  137500.25  150000.0
# Major_Category                   NaN        NaN       NaN
# Year_of_Study                    NaN        NaN       NaN
# Pre_Semester_GPA                3.21      3.521     3.998
# Weekly_GenAI_Hours               5.8      11.72      40.0
# Primary_Use_Case                 NaN        NaN       NaN
# Prompt_Engineering_Skill         NaN        NaN       NaN
# Tool_Diversity                   3.0        4.0       5.0
# Paid_Subscription                NaN        NaN       NaN
# Traditional_Study_Hours        11.18      14.71     35.86
# Perceived_AI_Dependency          3.0        5.0      10.0
# Institutional_Policy             NaN        NaN       NaN
# Anxiety_Level_During_Exams       4.0        6.0      10.0
# Post_Semester_GPA              3.421      3.749       4.0
# Skill_Retention_Score           76.0      85.19     100.0
# Burnout_Risk_Level               NaN        NaN       NaN
# Series([], dtype: int64)
# Major_Category value counts:
# /var/folders/9m/_19zklm12qq6ddw6q3zbq4r40000gn/T/ipykernel_28835/1102953455.py:23: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include=["object", "category"]).columns.tolist()
# Major_Category
# STEM          15059
# Business      12538
# Humanities     9994
# Medical        6476
# Arts           5933
# Name: count, dtype: int64
# Year_of_Study value counts:
# Year_of_Study
# Junior       11045
# Freshman     11031
# Senior       10634
# Sophomore     9860
# Graduate      7430
# Name: count, dtype: int64
# Primary_Use_Case value counts:
# Primary_Use_Case
# Debugging/Troubleshooting    12295
# Copywriting/Drafting         12011
# Ideation                     10721
# Summarizing_Reading           8633
# Direct_Answer_Generation      6340
# Name: count, dtype: int64
# Prompt_Engineering_Skill value counts:
# Prompt_Engineering_Skill
# Beginner        18495
# Intermediate    17696
# Advanced        13809
# Name: count, dtype: int64
# Institutional_Policy value counts:
# Institutional_Policy
# Allowed_With_Citation    25224
# Actively_Encouraged      14988
# Strict_Ban                9788
# Name: count, dtype: int64
# Burnout_Risk_Level value counts:
# Burnout_Risk_Level
# Medium    21144
# Low       16369
# High      12487
# Name: count, dtype: int64
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 33553      133554           STEM      Graduate             2.208
# 9427       109428           Arts      Graduate             2.931
# 199        100200           Arts     Sophomore             2.874
# 12447      112448        Medical        Junior             2.517
# 39489      139490       Business     Sophomore             2.927
# 42724      142725       Business      Freshman             3.830
# 10822      110823        Medical      Graduate             2.404
# 49498      149499     Humanities      Freshman             3.385
# 4144       104145        Medical        Senior             3.014
# 36958      136959           STEM      Freshman             2.847
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 33553                1.75   Direct_Answer_Generation             Intermediate
# 9427                 3.08                   Ideation                 Beginner
# 199                 14.28   Direct_Answer_Generation                 Advanced
# 12447                7.42       Copywriting/Drafting                 Beginner
# 39489                3.12       Copywriting/Drafting             Intermediate
# 42724                3.61       Copywriting/Drafting                 Beginner
# 10822                3.25   Direct_Answer_Generation                 Beginner
# 49498               13.92        Summarizing_Reading             Intermediate
# 4144                 3.24                   Ideation                 Beginner
# 36958                7.48  Debugging/Troubleshooting                 Beginner
#
#        Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 33553               1               True                     8.22
# 9427                3               True                    11.68
# 199                 3              False                    13.68
# 12447               1               True                     1.00
# 39489               3              False                     5.59
# 42724               3               True                    15.50
# 10822               1              False                     9.16
# 49498               3              False                    11.98
# 4144                2              False                    10.18
# 36958               1              False                     8.40
#
#        Perceived_AI_Dependency   Institutional_Policy  \
# 33553                        2    Actively_Encouraged
# 9427                         5    Actively_Encouraged
# 199                          6             Strict_Ban
# 12447                        1  Allowed_With_Citation
# 39489                        3    Actively_Encouraged
# 42724                        2  Allowed_With_Citation
# 10822                        4  Allowed_With_Citation
# 49498                        4  Allowed_With_Citation
# 4144                         3  Allowed_With_Citation
# 36958                        4             Strict_Ban
#
#        Anxiety_Level_During_Exams  Post_Semester_GPA  Skill_Retention_Score  \
# 33553                           2              2.582                  64.42
# 9427                            8              3.452                  82.34
# 199                             5              3.035                  87.08
# 12447                           1              2.754                  78.94
# 39489                           4              3.084                  63.73
# 42724                           3              3.725                  82.04
# 10822                           2              3.032                  56.49
# 49498                           8              3.392                  66.91
# 4144                            4              3.227                  90.19
# 36958                           3              3.024                  67.21
#
#       Burnout_Risk_Level
# 33553                Low
# 9427                 Low
# 199                 High
# 12447               High
# 39489                Low
# 42724                Low
# 10822               High
# 49498               High
# 4144                 Low
# 36958                Low
